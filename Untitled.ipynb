# %%
#define triangular mask geometry
left_bottom = [0, 539]
right_bottom = [900, 539]
apex = [450, 300]

#define a linear fit between triangle coordinates
fit_left = np.polyfit((left_bottom[0], apex[0]), (left_bottom[1], apex[1]), 1)
fit_right = np.polyfit((right_bottom[0], apex[0]), (right_bottom[1], apex[1]), 1)
fit_bottom = np.polyfit((left_bottom[0], right_bottom[0]), (left_bottom[1], right_bottom[1]), 1)





# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images_output directory.

#read in image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#define the dimension values x,y and copy the image to the colorselect variable
ysize = image.shape[0]
xsize = image.shape[1]
color_select = np.copy(image)

#define color threshold values for segmentation definitions
red_threshold = 210
green_threshold = 210
blue_threshold = 210
rgb_threshold = [red_threshold, green_threshold, blue_threshold]

#use the threshold values to set the output color to black for better visualization
thresholds = (image[:,:,0] < rgb_threshold[0]) \
            | (image[:,:,1] < rgb_threshold[1]) \
            | (image[:,:,2] < rgb_threshold[2])

color_select[thresholds] = [0,0,0]

#display the image
print("Basic image threshold visualization:")
plt.imshow(color_select)
plt.show()

#define image mask using the region_of_interest(img, vertices) function
img=np.copy(image)
vertices = np.array([[(0,img.shape[0]),(0.49*img.shape[1],0.58*img.shape[0]),(0.51*img.shape[1],0.58*img.shape[0]),(img.shape[1],img.shape[0])]],dtype=np.int32)
roi = region_of_interest(region_select, vertices)

print("Region of Interest image threshold visualization:")
plt.imshow(roi)
plt.show()

#convert image to gray scale
gray = grayscale(image)

#apply Gaussian smoothing/blurring
kernel_size = 5
blur_gray = gaussian_blur(gray, kernel_size)

#define edges with Canny filter
low_threshold = 57
high_threshold = 140
edges = canny(blur_gray, low_threshold, high_threshold)

#plot the image
print("Canny edges visualization:")
plt.imshow(edges, cmap='Greys_r')
plt.show()

#define hough lines
rho = 1
theta = np.pi/180
threshold = 5
min_line_len = 15
max_line_gap = 5

hough_lines = hough_lines(roi, rho, theta, threshold, min_line_len, max_line_gap)

plt.imshow(hough_lines)
plt.show()

#line_edges = weighted_img(hough_lines, image, α=0.8, β=1., γ=0.)

# %%
# Solution is available in the other "solution.py" tab
import tensorflow as tf


def run():
    output = None
    x = tf.placeholder(tf.int32)

    with tf.Session() as sess:
        # TODO: Feed the x tensor 123
        output = sess.run(x, feed_dict={x: 123})

    return output
